# %%
cp drive/MyDrive/Colab\ Notebooks/Evaluation.py drive/MyDrive/Colab\ Notebooks/SHADE.py drive/MyDrive/Colab\ Notebooks/function.py .

# %%
#pip install cec2013lsgo

# %%
# %%shell
# python Evaluation.py -h
# Out:
# usage: Evaluation.py [-h] [--LP LP]
#                      output_file
#                      {Sphere,Elliptic,Rastrigin,Ackley,Rosenbrock,Schwefel}
#                      max_fun_evals Pop_size Dimension
#
# Runs the SHADE algorithm
#
# positional arguments:
#   output_file           Name fo the file to save the output
#   {Sphere,Elliptic,Rastrigin,Ackley,Rosenbrock,Schwefel}
#                         Name of the function.
#   max_fun_evals         Maximum number of evaluations
#   Pop_size              Size of the population
#   Dimension             Dimension of the problem
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --LP LP               Size of the discrete memory for CR and F. Default is
#                         LP=Pop_size

# %%
cp drive/MyDrive/Colab\ Notebooks/planificador.cpp .

# %%
cp drive/MyDrive/Colab\ Notebooks/machines.txt .

# %%
# %%shell
# g++ planificador.cpp -o plan

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Sphere.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Sphere.txt

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Elliptic.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Elliptic.txt

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Rastrigin.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Rastrigin.txt

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Ackley.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Ackley.txt

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Rosenbrock.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Rosenbrock.txt

# %%
cp drive/MyDrive/Colab\ Notebooks/tasks_Schwefel.txt .

# %%
# %%shell
# ./plan machines.txt tasks_Schwefel.txt

# %%
# %%shell
# ./plan machines.txt tasks_1000.txt
# Out:
# /content/function.py:42: RuntimeWarning: overflow encountered in square
#   sq_csum=np.square(csum)
# /content/function.py:42: RuntimeWarning: overflow encountered in square
#   sq_csum=np.square(csum)
